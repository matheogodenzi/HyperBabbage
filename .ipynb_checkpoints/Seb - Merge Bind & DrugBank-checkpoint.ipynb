# %% [markdown]
# ## Insight for the medical dataset

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
from tqdm import tqdm
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ### Paths

# %%
DATA_PATH = './data/'
BINDINGDB = 'BindingDB_All.tsv'
DRUGBANK = 'parsed_DrugBank.csv'
output_file = 'intermediate_results.csv'

# %% [markdown]
# ### Loading the data

# %%
def load_BindingDB(file):
    file_path = DATA_PATH + file

    ## load the first row to get the number of columns
    df_first_row = pd.read_csv(file_path, sep='\t', nrows=1)

    ## number of columns to use
    df = pd.read_csv(file_path, sep='\t', header=0, usecols=range(df_first_row.shape[1]))
    return df

# %%
df = load_BindingDB(BINDINGDB)
# Out:
# C:\Users\sebge\AppData\Local\Temp\ipykernel_29384\2661906853.py:8: DtypeWarning: Columns (8,9,10,11,12,13,15,17,18,20,21,22,23,27,28,32,33,35,36,45,46,47,48,50,51,52,53,54,55,57,58,59,60,62,63,64,65,66,67,69,70,71,72,74,75,76,77,78,79,81,82,83,86,87,88,89,90,91,93,94,95,98,99,100,101,102,103,105,106,107,110,111,112,113,114,115,117,118,119,122,123,124,125,126,127,129,130,131,134,135,136,137,138,139,141,142,143,146,147,148,149,150,151,153,154,155,158,159,160,161,162,163,165,166,167,170,171,172,173,174,175,177,178,179,182,183,184,185,186,187,189,190,191) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, sep='\t', header=0, usecols=range(df_first_row.shape[1]))

# %%
print(f"Number of rows: {len(df)}")
print(f"Number of cols: {len(df.columns)}")
# Out:
# Number of rows: 2927609
# Number of cols: 194

# %%
import re
def keep_just_numeric(value):
    if type(value) != str:
        return -1
    
    cleaned_val = re.sub(r'[^\d.]+','', str(value)) ## There are random float / str in the dataset?? -> convert to str
    if(cleaned_val == ''): #It didn't contain any number?
        return -1
    return float(cleaned_val)

affinity_cols = ["Ki (nM)", "Kd (nM)"] ## Measures of binding affinity
ec_ic = ["EC50 (nM)", "IC50 (nM)"] #### Measures of inhibitory (IC50) and effective concentrations (EC50)
bind_unbind = ["kon (M-1-s-1)", "koff (s-1)"] ## Rates of binding / unbinding of ligands

binding_ligand_efficency_cols = affinity_cols + ec_ic + bind_unbind
filtered_df = df.copy()

for af_col in binding_ligand_efficency_cols:
    filtered_df[af_col] = filtered_df[af_col].apply(keep_just_numeric)
filtered_df.head()
# Out:
#    BindingDB Reactant_set_id  \
# 0                          1
# 1                          2
# 2                          3
# 3                          4
# 4                          5
#
#                                        Ligand SMILES  \
# 0  O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(CCCCCC(O)=...
# 1  O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(C\C=C\c2cn...
# 2  O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(CC2CC2)C(=...
# 3  OCCCCCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[C@@...
# 4  OCCCCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[C@@H...
#
#                                         Ligand InChI  \
# 0  InChI=1S/C31H42N2O7/c34-27(35)17-9-3-11-19-32-...
# 1  InChI=1S/C31H34N6O3/c38-29-27(17-23-9-3-1-4-10...
# 2  InChI=1S/C29H34N4O3/c34-27-25(16-21-8-3-1-4-9-...
# 3  InChI=1S/C29H40N2O4/c32-18-10-2-1-9-17-30-25(1...
# 4  InChI=1S/C28H38N2O4/c31-17-9-3-8-16-29-24(18-2...
#
#               Ligand InChI Key  BindingDB MonomerID  \
# 0  XGEGDSLAQZJGCW-HHGOQMMWSA-N               608734
# 1  UZLMEAPBHYEHAC-UNTBESQGSA-N                   22
# 2  HYNYUFZPPJMPOB-UTWJFGBXSA-N                   23
# 3  YXVAZXDWVZTGGD-VIJSPRBVSA-N                   24
# 4  WWTSWTPNILRSJX-XDZXDJIYSA-N                   25
#
#                                BindingDB Ligand Name  \
# 0  6-[(4R,5S,6S,7R)-4,7-dibenzyl-3-(5-carboxypent...
# 1  (4R,5S,6S,7R)-4,7-dibenzyl-5,6-dihydroxy-1,3-b...
# 2  (4R,5S,6S,7R)-4,7-dibenzyl-1-(cyclopropylmethy...
# 3  (4R,5S,6S,7R)-4,7-dibenzyl-1-(cyclopropylmethy...
# 4  (4R,5S,6S,7R)-4,7-dibenzyl-1-(cyclopropylmethy...
#
#                               Target Name  \
# 0  Dimer of Gag-Pol polyprotein [501-599]
# 1  Dimer of Gag-Pol polyprotein [501-599]
# 2  Dimer of Gag-Pol polyprotein [501-599]
# 3  Dimer of Gag-Pol polyprotein [501-599]
# 4  Dimer of Gag-Pol polyprotein [501-599]
#
#   Target Source Organism According to Curator or DataSource  Ki (nM)  \
# 0                     Human immunodeficiency virus 1            0.24
# 1                     Human immunodeficiency virus 1            0.25
# 2                     Human immunodeficiency virus 1            0.41
# 3                     Human immunodeficiency virus 1            0.80
# 4                     Human immunodeficiency virus 1            0.99
#
#    IC50 (nM)  ...  UniProt (SwissProt) Recommended Name of Target Chain.12  \
# 0       -1.0  ...                                                NaN
# 1       -1.0  ...                                                NaN
# 2       -1.0  ...                                                NaN
# 3       -1.0  ...                                                NaN
# 4       -1.0  ...                                                NaN
#
#    UniProt (SwissProt) Entry Name of Target Chain.12  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    UniProt (SwissProt) Primary ID of Target Chain.12  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    UniProt (SwissProt) Secondary ID(s) of Target Chain.12  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    UniProt (SwissProt) Alternative ID(s) of Target Chain.12  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   UniProt (TrEMBL) Submitted Name of Target Chain.12  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   UniProt (TrEMBL) Entry Name of Target Chain.12  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   UniProt (TrEMBL) Primary ID of Target Chain.12  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   UniProt (TrEMBL) Secondary ID(s) of Target Chain.12  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    UniProt (TrEMBL) Alternative ID(s) of Target Chain.12
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 194 columns]

# %% [markdown]
# ## Link to Drug Bank

# %%
drugbank = pd.read_csv(DATA_PATH + DRUGBANK, encoding='utf-8')
drugbank.head()
# Out:
#         id                 name        unii  \
# 0  DB00001            Lepirudin  Y43GF64R34
# 1  DB00002            Cetuximab  PQX0D8J21J
# 2  DB00003         Dornase alfa  953A26OA1Y
# 3  DB00004  Denileukin diftitox  25E79B5CTM
# 4  DB00005           Etanercept  OP401G7OJC
#
#                                             toxicity      class_kingdom  \
# 0  The acute toxicity of intravenous lepirudin wa...  Organic Compounds
# 1  The intravenous LD<sub>50</sub> is > 300 mg/kg...  Organic Compounds
# 2  Adverse reactions occur at a frequency of < 1/...  Organic Compounds
# 3                                                NaN  Organic Compounds
# 4                                                NaN  Organic Compounds
#
#   class_superclass                                           synonyms  \
# 0    Organic Acids  [Leu1, Thr2]-63-desulfohirudin|Desulfatohirudi...
# 1    Organic Acids                    Cetuximab|Cétuximab|Cetuximabum
# 2    Organic Acids  Deoxyribonuclease (human clone 18-1 protein mo...
# 3    Organic Acids  Denileukin|Denileukin diftitox|Interleukin-2/d...
# 4    Organic Acids  Etanercept|etanercept-szzs|etanercept-ykro|Rec...
#
#                                           categories  \
# 0  Amino Acids, Peptides, and Proteins|Anticoagul...
# 1  Amino Acids, Peptides, and Proteins|Antibodies...
# 2  Amino Acids, Peptides, and Proteins|Cough and ...
# 3  ADP Ribose Transferases|Amino Acids, Peptides,...
# 4  Agents reducing cytokine levels|Amino Acids, P...
#
#                     patent_approved  \
# 0                        1993-01-19
# 1                        1999-03-02
# 2             2005-02-22|2004-10-26
# 3                               NaN
# 4  2009-06-16|2000-03-14|2007-10-02
#
#                                          interaction     pubchem  \
# 0  DB06605|DB06695|DB01254|DB01609|DB01586|DB0212...  46507011.0
# 1  DB00255|DB00269|DB00286|DB00655|DB00783|DB0089...  46507042.0
# 2                                                NaN  46507792.0
# 3  DB00012|DB00016|DB08894|DB09107|DB00281|DB0029...  46506950.0
# 4  DB08879|DB00531|DB06643|DB00065|DB00008|DB0001...  46506732.0
#
#           chembl SMILES InChI  chebi  bindingdb
# 0  CHEMBL1201666    NaN   NaN    NaN        NaN
# 1  CHEMBL1201577    NaN   NaN    NaN        NaN
# 2  CHEMBL1201431    NaN   NaN    NaN        NaN
# 3  CHEMBL1201550    NaN   NaN    NaN        NaN
# 4  CHEMBL1201572    NaN   NaN    NaN        NaN

# %%
len(filtered_df['DrugBank ID of Ligand'].dropna())
# Out:
# 87465

# %%
smile_merged = pd.merge(filtered_df, drugbank, left_on='Ligand SMILES', right_on='SMILES')
len(smile_merged)
# Out:
# 6191

# %%
# Rename columns in BindingDB to unify naming conventions
BindingDB = filtered_df.rename(columns={
    'PubChem CID': 'PubChem_CID',
    'ChEBI ID of Ligand': 'ChEBI_ID',
    'ChEMBL ID of Ligand': 'ChEMBL_ID',
    'DrugBank ID of Ligand': 'DrugBank_ID',
    'KEGG ID of Ligand': 'KEGG_ID',
    'ZINC ID of Ligand': 'ZINC_ID',
    'Ligand SMILES': 'SMILES',
    'Ligand InChI Key': 'InChI_Key',
    'BindingDB MonomerID': 'BindingDB_ID',
})

# Rename columns in DrugBank to unify naming conventions
DrugBank = drugbank.rename(columns={
    'chebi': 'ChEBI_ID',
    'chembl': 'ChEMBL_ID',
    'pubchem': 'PubChem_CID',
    'PubChem Substance': 'PubChem_SID',
    'id': 'DrugBank_ID',
    'bindingdb': 'BindingDB_ID',
    'ZINC': 'ZINC_ID',
    'SMILES': 'SMILES',
    'InChI': 'InChI_Key',
    'KEGG Compound': 'KEGG_ID'
})

BindingDB['Unique_ID'] = np.arange(len(BindingDB))
DrugBank['Unique_DrugBank_ID'] = np.arange(len(DrugBank))

# %%
import pandas as pd
import os
import gc

# Ensure the output file does not exist from previous runs
if os.path.exists(output_file):
    os.remove(output_file)

# List of identifiers to merge on
identifier_columns = [
    'PubChem_CID',
    'PubChem_SID',
    'ChEBI_ID',
    'ChEMBL_ID',
    'DrugBank_ID',
    'BindingDB_ID',
    'ZINC_ID',
    'SMILES',
    'InChI',
    'InChI_Key'
]

# Function to process and merge on each identifier individually
def merge_on_identifiers(df1, df2, identifiers, output_file):
    for identifier in identifiers:
        if identifier in df1.columns and identifier in df2.columns:
            print(f"Processing identifier: {identifier}")
            
            # Drop rows with NaN in the identifier columns
            df1_id = df1.dropna(subset=[identifier])
            df2_id = df2.dropna(subset=[identifier])
            
            # Convert identifier columns to string to avoid type mismatches
            if identifier in ['BindingDB_ID']:
                df1_id[identifier] = df1_id[identifier].astype(int)
                df2_id[identifier] = df2_id[identifier].astype(int)
            else:
                df1_id[identifier] = df1_id[identifier].astype(str)
                df2_id[identifier] = df2_id[identifier].astype(str)
            
            # Perform the merge
            merged_df = pd.merge(
                df1_id, df2_id, 
                on=identifier, 
                how='inner', 
                suffixes=('_BindingDB', '_DrugBank')
            )
            
            if not merged_df.empty:
                # Add a column to indicate which identifier was matched
                merged_df['Matched_On'] = identifier
                
                # Write to CSV in append mode
                merged_df.to_csv(
                    output_file, 
                    mode='a', 
                    index=False, 
                    header=not os.path.exists(output_file)
                )
            
            # Clean up memory
            del df1_id, df2_id, merged_df
            gc.collect()

# Perform the merge
merge_on_identifiers(BindingDB, DrugBank, identifier_columns, output_file)
# Out:
# Processing identifier: PubChem_CID
# C:\Users\sebge\AppData\Local\Temp\ipykernel_29384\434813518.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_id[identifier] = df1_id[identifier].astype(str)
# C:\Users\sebge\AppData\Local\Temp\ipykernel_29384\434813518.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_id[identifier] = df2_id[identifier].astype(str)
# Processing identifier: ChEBI_ID
# C:\Users\sebge\AppData\Local\Temp\ipykernel_29384\434813518.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_id[identifier] = df1_id[identifier].astype(str)
# C:\Users\sebge\AppData\Local\Temp\ipykernel_29384\434813518.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_id[identifier] = df2_id[identifier].astype(str)
# Processing identifier: ChEMBL_ID
# C:\Users\sebge\AppData\Local\Temp\ipykernel_29384\434813518.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_id[identifier] = df1_id[identifier].astype(str)
# C:\Users\sebge\AppData\Local\Temp\ipykernel_29384\434813518.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_id[identifier] = df2_id[identifier].astype(str)
# Processing identifier: DrugBank_ID
# C:\Users\sebge\AppData\Local\Temp\ipykernel_29384\434813518.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_id[identifier] = df1_id[identifier].astype(str)
# Processing identifier: BindingDB_ID
# C:\Users\sebge\AppData\Local\Temp\ipykernel_29384\434813518.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_id[identifier] = df2_id[identifier].astype(int)
# Processing identifier: SMILES
# C:\Users\sebge\AppData\Local\Temp\ipykernel_29384\434813518.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_id[identifier] = df2_id[identifier].astype(str)
# Processing identifier: InChI_Key
# C:\Users\sebge\AppData\Local\Temp\ipykernel_29384\434813518.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_id[identifier] = df1_id[identifier].astype(str)
# C:\Users\sebge\AppData\Local\Temp\ipykernel_29384\434813518.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_id[identifier] = df2_id[identifier].astype(str)

# %%
merged_df = pd.read_csv(output_file)
# Out:
# C:\Users\sebge\AppData\Local\Temp\ipykernel_29384\3797673924.py:1: DtypeWarning: Columns (15,17,20,21,35,45,46,47,48,50,51,52,53,54,55,57,58,59,62,63,64,65,66,67,69,70,71,74,75,76,77,78,79,86,87,88,89,90,91,98,99,100,101,102,103,105,106,107,110,111,112,113,114,115,122,123,124,125,126,127,129,130,131,134,135,136,137,138,139,146,147,148,149,150,151,158,159,160,161,162,163,170,171,172,173,174,175,182,183,184,185,186,187,204,205,208) have mixed types. Specify dtype option on import or set low_memory=False.
#   merged_df = pd.read_csv(output_file)

# %%
merged_df['Matched_On'].value_counts()
# Out:
# Matched_On
# InChI_Key       147426
# BindingDB_ID    138645
# ChEMBL_ID        96639
# DrugBank_ID      83430
# ChEBI_ID         74904
# SMILES            6191
# PubChem_CID          9
# Name: count, dtype: int64

# %%
len(merged_df)
# Out:
# 547244

# %%
merged_df['Unique_ID'].nunique()
# Out:
# 152520

# %%
merged_df.drop_duplicates(subset=['Unique_ID'], inplace=True)

# %%
merged_df['Unique_DrugBank_ID'].nunique()
# Out:
# 5777

# %%
DrugBank['Unique_DrugBank_ID'].nunique()
# Out:
# 16581

# %%
merged_df['Unique_DrugBank_ID'].nunique() / DrugBank['Unique_DrugBank_ID'].nunique()
# Out:
# 0.3484108316748085

# %%
len(DrugBank)
# Out:
# 16581

# %%
merged_df['Unique_DrugBank_ID'].nunique() / len(BindingDB) * 100
# Out:
# 0.19732826343955087

# %%
BindingDB.loc[BindingDB['DrugBank_ID'].dropna().index][['DrugBank_ID', 'SMILES', 'BindingDB_ID']].head()
# Out:
#     DrugBank_ID                                             SMILES  \
# 29      DB06910  O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(CC=C)C(=O)...
# 131     DB06910  O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(CC=C)C(=O)...
# 235     DB01264  CC(C)CN(C[C@@H](O)[C@H](Cc1ccccc1)NC(=O)O[C@H]...
# 246     DB01264  CC(C)CN(C[C@@H](O)[C@H](Cc1ccccc1)NC(=O)O[C@H]...
# 814     DB02033  Oc1c2CCCCCCc2oc(=O)c1[C@@H](C1CC1)c1cccc(NS(=O...
#
#      BindingDB_ID
# 29            152
# 131           152
# 235          8125
# 246          8125
# 814           763

# %%
DrugBank.head(2)
# Out:
#   DrugBank_ID       name        unii  \
# 0     DB00001  Lepirudin  Y43GF64R34
# 1     DB00002  Cetuximab  PQX0D8J21J
#
#                                             toxicity      class_kingdom  \
# 0  The acute toxicity of intravenous lepirudin wa...  Organic Compounds
# 1  The intravenous LD<sub>50</sub> is > 300 mg/kg...  Organic Compounds
#
#   class_superclass                                           synonyms  \
# 0    Organic Acids  [Leu1, Thr2]-63-desulfohirudin|Desulfatohirudi...
# 1    Organic Acids                    Cetuximab|Cétuximab|Cetuximabum
#
#                                           categories patent_approved  \
# 0  Amino Acids, Peptides, and Proteins|Anticoagul...      1993-01-19
# 1  Amino Acids, Peptides, and Proteins|Antibodies...      1999-03-02
#
#                                          interaction  PubChem_CID  \
# 0  DB06605|DB06695|DB01254|DB01609|DB01586|DB0212...   46507011.0
# 1  DB00255|DB00269|DB00286|DB00655|DB00783|DB0089...   46507042.0
#
#        ChEMBL_ID SMILES InChI_Key  ChEBI_ID  BindingDB_ID  Unique_DrugBank_ID
# 0  CHEMBL1201666    NaN       NaN       NaN           NaN                   0
# 1  CHEMBL1201577    NaN       NaN       NaN           NaN                   1

# %%
# Left join binding db with merged_df (on Unique_ID), don't duplicate columns though
binding_readded = pd.merge(BindingDB, merged_df, on='Unique_ID', how='left', suffixes=('', '_y'))

# %%
binding_readded.head(2)
# Out:
#    BindingDB Reactant_set_id  \
# 0                          1
# 1                          2
#
#                                               SMILES  \
# 0  O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(CCCCCC(O)=...
# 1  O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(C\C=C\c2cn...
#
#                                         Ligand InChI  \
# 0  InChI=1S/C31H42N2O7/c34-27(35)17-9-3-11-19-32-...
# 1  InChI=1S/C31H34N6O3/c38-29-27(17-23-9-3-1-4-10...
#
#                      InChI_Key  BindingDB_ID  \
# 0  XGEGDSLAQZJGCW-HHGOQMMWSA-N        608734
# 1  UZLMEAPBHYEHAC-UNTBESQGSA-N            22
#
#                                BindingDB Ligand Name  \
# 0  6-[(4R,5S,6S,7R)-4,7-dibenzyl-3-(5-carboxypent...
# 1  (4R,5S,6S,7R)-4,7-dibenzyl-5,6-dihydroxy-1,3-b...
#
#                               Target Name  \
# 0  Dimer of Gag-Pol polyprotein [501-599]
# 1  Dimer of Gag-Pol polyprotein [501-599]
#
#   Target Source Organism According to Curator or DataSource  Ki (nM)  \
# 0                     Human immunodeficiency virus 1            0.24
# 1                     Human immunodeficiency virus 1            0.25
#
#    IC50 (nM)  ...  categories  patent_approved  interaction  \
# 0       -1.0  ...         NaN              NaN          NaN
# 1       -1.0  ...         NaN              NaN          NaN
#
#    ChEMBL_ID_DrugBank  SMILES_DrugBank InChI_Key_DrugBank ChEBI_ID_DrugBank  \
# 0                 NaN              NaN                NaN               NaN
# 1                 NaN              NaN                NaN               NaN
#
#   BindingDB_ID_DrugBank Unique_DrugBank_ID  Matched_On
# 0                   NaN                NaN         NaN
# 1                   NaN                NaN         NaN
#
# [2 rows x 406 columns]

# %%
all_cols = list(binding_readded.columns)
cols_to_keep = []

for col in all_cols:
    if not ('_y' in col and col.split('_y')[0] in list(BindingDB.columns)):
        cols_to_keep.append(col)

# %%
# Keep only the columns in cols_to_keep
cleaned_readded = binding_readded[cols_to_keep]

# %%
cleaned_readded
# Out:
#          BindingDB Reactant_set_id  \
# 0                                1
# 1                                2
# 2                                3
# 3                                4
# 4                                5
# ...                            ...
# 2927604                   51531022
# 2927605                   51531023
# 2927606                   51531024
# 2927607                   51531025
# 2927608                   51531026
#
#                                                     SMILES  \
# 0        O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(CCCCCC(O)=...
# 1        O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(C\C=C\c2cn...
# 2        O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(CC2CC2)C(=...
# 3        OCCCCCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[C@@...
# 4        OCCCCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[C@@H...
# ...                                                    ...
# 2927604  CC[C@H]1CN(Cc2cc(C)cc(CC(O)=O)c2)CCN1c1nc2ccc(...
# 2927605  CC[C@@H]1CN(Cc2cc(C)cc(CC(O)=O)c2)CCN1c1nc2ccc...
# 2927606  CC(C)[C@@H]1CN(Cc2cc(C)cc(CC(O)=O)c2)CCN1c1nc2...
# 2927607                COc1ccc(cc1)N(C)c1nc(C)nc2[nH]ccc12
# 2927608             COc1ccc(\C=C/c2cc(OC)c(OC)c(OC)c2)cc1O
#
#                                               Ligand InChI  \
# 0        InChI=1S/C31H42N2O7/c34-27(35)17-9-3-11-19-32-...
# 1        InChI=1S/C31H34N6O3/c38-29-27(17-23-9-3-1-4-10...
# 2        InChI=1S/C29H34N4O3/c34-27-25(16-21-8-3-1-4-9-...
# 3        InChI=1S/C29H40N2O4/c32-18-10-2-1-9-17-30-25(1...
# 4        InChI=1S/C28H38N2O4/c31-17-9-3-8-16-29-24(18-2...
# ...                                                    ...
# 2927604  InChI=1S/C24H26F3N3O2S/c1-3-19-14-29(13-17-9-1...
# 2927605  InChI=1S/C24H26F3N3O2S/c1-3-19-14-29(13-17-9-1...
# 2927606  InChI=1S/C25H28F3N3O2S/c1-15(2)21-14-30(13-18-...
# 2927607  InChI=1S/C15H16N4O/c1-10-17-14-13(8-9-16-14)15...
# 2927608  InChI=1S/C18H20O5/c1-20-15-8-7-12(9-14(15)19)5...
#
#                            InChI_Key  BindingDB_ID  \
# 0        XGEGDSLAQZJGCW-HHGOQMMWSA-N        608734
# 1        UZLMEAPBHYEHAC-UNTBESQGSA-N            22
# 2        HYNYUFZPPJMPOB-UTWJFGBXSA-N            23
# 3        YXVAZXDWVZTGGD-VIJSPRBVSA-N            24
# 4        WWTSWTPNILRSJX-XDZXDJIYSA-N            25
# ...                              ...           ...
# 2927604  ZBKXSRSXIGZPCY-IBGZPJMESA-N      50615961
# 2927605  ZBKXSRSXIGZPCY-LJQANCHMSA-N      50615962
# 2927606  RVZUBLMVVIWYLZ-NRFANRHFSA-N      50615964
# 2927607  HKPVMULFKBBABY-UHFFFAOYSA-N      50615967
# 2927608  HVXBOLULGPECHP-WAYWQWQTSA-N      50005480
#
#                                      BindingDB Ligand Name  \
# 0        6-[(4R,5S,6S,7R)-4,7-dibenzyl-3-(5-carboxypent...
# 1        (4R,5S,6S,7R)-4,7-dibenzyl-5,6-dihydroxy-1,3-b...
# 2        (4R,5S,6S,7R)-4,7-dibenzyl-1-(cyclopropylmethy...
# 3        (4R,5S,6S,7R)-4,7-dibenzyl-1-(cyclopropylmethy...
# 4        (4R,5S,6S,7R)-4,7-dibenzyl-1-(cyclopropylmethy...
# ...                                                    ...
# 2927604                                      CHEMBL5268424
# 2927605                                      CHEMBL5272996
# 2927606                                      CHEMBL5277165
# 2927607                                      CHEMBL1275943
# 2927608  (-)-combretastatin::(Z)-3'-hydroxy-3,4,4',5-te...
#
#                                               Target Name  \
# 0                  Dimer of Gag-Pol polyprotein [501-599]
# 1                  Dimer of Gag-Pol polyprotein [501-599]
# 2                  Dimer of Gag-Pol polyprotein [501-599]
# 3                  Dimer of Gag-Pol polyprotein [501-599]
# 4                  Dimer of Gag-Pol polyprotein [501-599]
# ...                                                   ...
# 2927604  Peroxisome proliferator-activated receptor gamma
# 2927605  Peroxisome proliferator-activated receptor gamma
# 2927606  Peroxisome proliferator-activated receptor gamma
# 2927607                Similar to alpha-tubulin isoform 1
# 2927608                Similar to alpha-tubulin isoform 1
#
#         Target Source Organism According to Curator or DataSource  Ki (nM)  \
# 0                           Human immunodeficiency virus 1            0.24
# 1                           Human immunodeficiency virus 1            0.25
# 2                           Human immunodeficiency virus 1            0.41
# 3                           Human immunodeficiency virus 1            0.80
# 4                           Human immunodeficiency virus 1            0.99
# ...                                                    ...             ...
# 2927604                                       Mus musculus           -1.00
# 2927605                                       Mus musculus           -1.00
# 2927606                                       Mus musculus           -1.00
# 2927607                                                NaN           -1.00
# 2927608                                                NaN           -1.00
#
#          IC50 (nM)  ...                                         categories  \
# 0             -1.0  ...                                                NaN
# 1             -1.0  ...                                                NaN
# 2             -1.0  ...                                                NaN
# 3             -1.0  ...                                                NaN
# 4             -1.0  ...                                                NaN
# ...            ...  ...                                                ...
# 2927604       -1.0  ...                                                NaN
# 2927605       -1.0  ...                                                NaN
# 2927606       -1.0  ...                                                NaN
# 2927607     2600.0  ...                                                NaN
# 2927608     1000.0  ...  Antineoplastic Agents|Antineoplastic Agents, P...
#
#          patent_approved                                        interaction  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
# ...                  ...                                                ...
# 2927604              NaN                                                NaN
# 2927605              NaN                                                NaN
# 2927606              NaN                                                NaN
# 2927607              NaN                                                NaN
# 2927608              NaN  DB00012|DB00016|DB08894|DB09107|DB00281|DB0029...
#
#          ChEMBL_ID_DrugBank                               SMILES_DrugBank  \
# 0                       NaN                                           NaN
# 1                       NaN                                           NaN
# 2                       NaN                                           NaN
# 3                       NaN                                           NaN
# 4                       NaN                                           NaN
# ...                     ...                                           ...
# 2927604                 NaN                                           NaN
# 2927605                 NaN                                           NaN
# 2927606                 NaN                                           NaN
# 2927607                 NaN                                           NaN
# 2927608                 NaN  COC1=CC=C(\C=C/C2=CC(OC)=C(OC)C(OC)=C2)C=C1O
#
#                   InChI_Key_DrugBank ChEBI_ID_DrugBank BindingDB_ID_DrugBank  \
# 0                                NaN               NaN                   NaN
# 1                                NaN               NaN                   NaN
# 2                                NaN               NaN                   NaN
# 3                                NaN               NaN                   NaN
# 4                                NaN               NaN                   NaN
# ...                              ...               ...                   ...
# 2927604                          NaN               NaN                   NaN
# 2927605                          NaN               NaN                   NaN
# 2927606                          NaN               NaN                   NaN
# 2927607                          NaN               NaN                   NaN
# 2927608  HVXBOLULGPECHP-WAYWQWQTSA-N          181391.0            50005480.0
#
#         Unique_DrugBank_ID  Matched_On
# 0                      NaN         NaN
# 1                      NaN         NaN
# 2                      NaN         NaN
# 3                      NaN         NaN
# 4                      NaN         NaN
# ...                    ...         ...
# 2927604                NaN         NaN
# 2927605                NaN         NaN
# 2927606                NaN         NaN
# 2927607                NaN         NaN
# 2927608            12630.0   ChEMBL_ID
#
# [2927609 rows x 218 columns]

# %% [markdown]
# ### Add Protein Data from DrugBank

# %%
DrugBankProteins = pd.read_csv('data/parsed_proteins_DrugBank.csv')
DrugBankProteins.rename(columns={'id': 'drugbank_swissprot_id'}, inplace=True)

# %%
complete_merged_df = pd.merge(cleaned_readded, DrugBankProteins, left_on='UniProt (SwissProt) Primary ID of Target Chain', right_on='drugbank_swissprot_id', how='left')

# %%
complete_merged_df['drugbank_swissprot_id'].notna().sum() / len(complete_merged_df)
# Out:
# 0.7263866178851069

# %%
complete_merged_df.to_csv('Merged Binding DrugBank with Proteins.csv', index=False)

# %%
import os
if os.path.exists(output_file):
    os.remove(output_file)
